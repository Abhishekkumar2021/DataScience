# %%
import pandas as pd

# %%
df = pd.read_csv('./weatherHistory.csv')
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
rows,cols = df.shape
print(rows)
print(cols)
# Out:
# 96453
# 12

# %%
df.head(20)
# Out:
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 0   2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1   2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2   2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3   2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4   2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5   2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6   2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7   2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8   2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9   2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain        16.016667
# ...

# %%
df.tail(10)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96443  2016-09-09 14:00:00.000 +0200  Partly Cloudy        rain
# 96444  2016-09-09 15:00:00.000 +0200  Partly Cloudy        rain
# 96445  2016-09-09 16:00:00.000 +0200  Partly Cloudy        rain
# 96446  2016-09-09 17:00:00.000 +0200  Partly Cloudy        rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96443        30.894444                 29.450000      0.28            14.7798
# 96444        31.083333                 29.616667      0.28            15.5043
# ...

# %%
df[2:5]
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 2                     204          14.9569           0               1015.94
# 3                     269          15.8263           0               1016.41
# 4                     259          15.8263           0               1016.51
#
#                        Daily Summary
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# ...

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.Summary
# Out:
# 0        Partly Cloudy
# 1        Partly Cloudy
# 2        Mostly Cloudy
# 3        Partly Cloudy
# 4        Mostly Cloudy
#              ...
# 96448    Partly Cloudy
# 96449    Partly Cloudy
# 96450    Partly Cloudy
# 96451    Partly Cloudy
# 96452    Partly Cloudy
# Name: Summary, Length: 96453, dtype: object

# %%
type(df['Apparent Temperature (C)'])
# Out:
# pandas.core.series.Series

# %%
df[['Apparent Temperature (C)','Wind Bearing (degrees)']]
# Out:
#        Apparent Temperature (C)  Wind Bearing (degrees)
# 0                      7.388889                     251
# 1                      7.227778                     259
# 2                      9.377778                     204
# 3                      5.944444                     269
# 4                      6.977778                     259
# ...                         ...                     ...
# 96448                 26.016667                      31
# 96449                 24.583333                      20
# 96450                 22.038889                      30
# 96451                 21.522222                      20
# 96452                 20.438889                      39
#
# [96453 rows x 2 columns]

# %%
df['Temperature (C)'].max()
# Out:
# 39.90555556

# %%
df['Temperature (C)'].min()
# Out:
# -21.82222222

# %%
df['Temperature (C)'].mean()
# Out:
# 11.93267843751985

# %%
df['Temperature (C)'].median()
# Out:
# 12.0

# %%
df['Temperature (C)'].std()
# Out:
# 9.55154632065504

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df[df['Apparent Temperature (C)']>=38]
# Pandas works like as sql...this line can be read as give me all the rows where Apparaent temperature is greater than or equal to 38 degree celsius
# Out:
#                       Formatted Date        Summary Precip Type  \
# 9903   2007-08-24 15:00:00.000 +0200          Clear        rain
# 38919  2010-07-17 15:00:00.000 +0200  Mostly Cloudy        rain
# 65533  2013-07-29 13:00:00.000 +0200          Clear        rain
# 65534  2013-07-29 14:00:00.000 +0200  Partly Cloudy        rain
# 65535  2013-07-29 15:00:00.000 +0200  Partly Cloudy        rain
# 66087  2013-06-21 15:00:00.000 +0200  Partly Cloudy        rain
# 66111  2013-06-22 15:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 9903         36.972222                 38.377778      0.32            10.5294
# 38919        33.794444                 38.116667      0.51             7.5670
# 65533        37.266667                 38.661111      0.32            13.7494
# 65534        37.072222                 38.255556      0.31            15.1501
# ...

# %%
df[df['Apparent Temperature (C)']==df['Apparent Temperature (C)'].max()]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 66111  2013-06-22 15:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 66111        34.955556                 39.344444      0.47             12.397
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 66111                     213            11.27           0
#
#        Pressure (millibars)               Daily Summary
# 66111               1011.12  Partly cloudy until night.

# %%
df['Formatted Date'][df['Apparent Temperature (C)']>=38]
# Out:
# 9903     2007-08-24 15:00:00.000 +0200
# 38919    2010-07-17 15:00:00.000 +0200
# 65533    2013-07-29 13:00:00.000 +0200
# 65534    2013-07-29 14:00:00.000 +0200
# 65535    2013-07-29 15:00:00.000 +0200
# 66087    2013-06-21 15:00:00.000 +0200
# 66111    2013-06-22 15:00:00.000 +0200
# Name: Formatted Date, dtype: object

# %%
df[['Formatted Date','Apparent Temperature (C)']][df['Apparent Temperature (C)']>=38]
# Out:
#                       Formatted Date  Apparent Temperature (C)
# 9903   2007-08-24 15:00:00.000 +0200                 38.377778
# 38919  2010-07-17 15:00:00.000 +0200                 38.116667
# 65533  2013-07-29 13:00:00.000 +0200                 38.661111
# 65534  2013-07-29 14:00:00.000 +0200                 38.255556
# 65535  2013-07-29 15:00:00.000 +0200                 38.416667
# 66087  2013-06-21 15:00:00.000 +0200                 38.122222
# 66111  2013-06-22 15:00:00.000 +0200                 39.344444

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
df.set_index('Formatted Date',inplace=True)
# Inplace means change the df itself inspite of giving new df
# Out:
#                                      Summary Precip Type  Temperature (C)  \
# Formatted Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# ...                                      ...         ...              ...
# 2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain        26.016667
# 2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain        24.583333
# 2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain        22.038889
# 2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain        21.522222
# 2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain        20.438889
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#        level_0  index                 Formatted Date        Summary  \
# 0            0      0  2006-04-01 00:00:00.000 +0200  Partly Cloudy
# 1            1      1  2006-04-01 01:00:00.000 +0200  Partly Cloudy
# 2            2      2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# 3            3      3  2006-04-01 03:00:00.000 +0200  Partly Cloudy
# 4            4      4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy
# ...        ...    ...                            ...            ...
# 96448    96448  96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy
# 96449    96449  96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy
# 96450    96450  96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy
# 96451    96451  96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy
# 96452    96452  96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy
#
#       Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  \
# 0            rain         9.472222                  7.388889      0.89
# ...
